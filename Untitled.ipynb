# %%
import pandas as pd
import tensorflow as tf
import tensorflow.compat.v1.keras.backend as K
print(tf.config.experimental.list_physical_devices('GPU'))
import pickle
import matplotlib.pyplot as plt
import numpy as np
import PIL
from matplotlib.image import imread
import json
import pickle
import keras
from tensorflow.keras import layers
import os
from matplotlib import image
from tensorflow.compat.v1 import ConfigProto
from tensorflow.compat.v1 import InteractiveSession
from custom_layers import Scale
from scipy.spatial import cKDTree
import cv2
config = ConfigProto()
config.gpu_options.allow_growth = True
session = InteractiveSession(config=config)
# Out:
# [PhysicalDevice(name='/physical_device:GPU:0', device_type='GPU')]

# %%
# Load the TensorBoard notebook extension
# %load_ext tensorboard

# %%
# Clear any logs from previous runs
# %rm -rf ./logs/

# %%
print(np.unique(df_train_y[0]))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-4-d6f8fe245f28> in <module>
# ----> 1 print(np.unique(df_train_y[0]))
#
# NameError: name 'df_train_y' is not defined

# %%
IMG_WIDTH = 512
IMG_HEIGHT = 512
IMG_CHANNELS = 3

# %%
TRAIN_PATH = '/home/rafa/Desktop/Projects/AVA/Kvasir-SEG/images'

train_ids = (os.listdir(TRAIN_PATH))

# %%
print(len(train_ids))
# Out:
# 1000

# %%
x_train = np.zeros((len(train_ids), IMG_HEIGHT, IMG_WIDTH, IMG_CHANNELS), dtype=np.uint8)
y_train = np.zeros((len(train_ids), IMG_HEIGHT, IMG_WIDTH, 1), dtype=np.uint8)

# %%
for i in range(1000):
    img = cv2.imread(os.path.join('Kvasir-SEG','images',train_ids[i]),cv2.IMREAD_COLOR)
    x_train[i] = cv2.GaussianBlur(img,(5,5),cv2.BORDER_DEFAULT) 
    y_train[i] =np.expand_dims(\
    np.array(cv2.imread(os.path.join('Kvasir-SEG','binary_masks',train_ids[i]),\
    cv2.IMREAD_GRAYSCALE)),axis=-1)

# %%
COLORMAP = np.array([[255 , 85, 170], [ 85 ,170 , 85], [255 ,  0 , 85],
 [170 ,255 ,170], [170 ,  0 ,255], [  0 ,170,  85], 
 [  0 ,255,  85], [170,  85 ,170], [85,  0 , 0], 
 [ 85 ,255 ,  0], [ 85 ,  0 ,170], [170, 255 , 85], 
 [255 ,  0 ,170], [  0 ,170, 255], [170 ,  0 ,  0], 
 [255, 170 ,  0], [170 , 85 , 85], [0 ,0 ,0], 
 [170 , 85,   0],[255 ,170 , 85], [ 0 ,85 , 0],
[  0, 255 ,  0], [  0 ,  0, 255], [85 , 0 ,85], 
[255 ,170 ,170], [ 0  ,0 ,85], [ 85 , 85, 170], 
[170   ,0 , 85], [  0 ,170 ,  0], [  0 ,255 ,255], 
[  0  , 0 ,170], [ 85  , 0 ,255], [ 85 ,170 ,170], 
[255  ,85 ,  0], [  0  ,85 ,255], [170, 255 ,  0], 
[ 85 ,170 ,  0], [85 ,85 , 0], [  0 ,255 ,170], 
[ 0 ,85 ,85], [85 ,85 ,85], [255  ,85 , 85],
[170  , 0 ,170], [170 ,170  ,85], [170 ,170 ,170], 
[  0  ,85 ,170], [ 85 ,255 , 85],[  0 ,170 ,170],
[170 ,170  , 0], [170  ,85 ,255], [ 85 , 85 ,255], 
[255  , 0 ,255]])

# %%
def resize(item):
        im = item
        imResize = im.resize((512,512), PIL.Image.ANTIALIAS)
        return imResize

# %%
for dire in os.listdir(os.path.join("dataset", "train","images")):
    image = PIL.Image.open(os.path.join("dataset", "train","images",dire))
    image = resize(image)
    df_train_x.append(np.array(image))
    
# for dire in os.listdir(os.path.join("dataset", "train","groundtruth_single")):
#     image = PIL.Image.open(os.path.join("dataset", "train","groundtruth_single",dire))
#     df_train_y.append(np.array(image))

for dire in os.listdir(os.path.join("dataset", "train","groundtruth")):
    image = PIL.Image.open(os.path.join("dataset", "train","groundtruth",dire))
    image = resize(image)
    df_train_y.append(np.array(image))

for dire in os.listdir(os.path.join("dataset", "test","images")):
    image = PIL.Image.open(os.path.join("dataset", "test","images",dire))
    image = resize(image)
    df_test_x.append(np.array(image))
    
# for dire in os.listdir(os.path.join("dataset", "test","groundtruth_single")):
#     image = PIL.Image.open(os.path.join("dataset", "test","groundtruth_single",dire))
#     df_test_y.append(np.array(image))

for dire in os.listdir(os.path.join("dataset", "test","groundtruth")):
    image = PIL.Image.open(os.path.join("dataset", "test","groundtruth",dire))
    image = resize(image)
    df_test_y.append(np.array(image))
                           
for dire in os.listdir(os.path.join("dataset", "trainval","images")):
    image = PIL.Image.open(os.path.join("dataset", "trainval","images",dire))
    image = resize(image)
    df_val_x.append(np.array(image))
    
# for dire in os.listdir(os.path.join("dataset", "trainval","groundtruth_single")):
#     image = PIL.Image.open(os.path.join("dataset", "trainval","groundtruth_single",dire))
#     df_val_y.append(np.array(image))

for dire in os.listdir(os.path.join("dataset", "trainval","groundtruth")):
    image = PIL.Image.open(os.path.join("dataset", "trainval","groundtruth",dire))
    image = resize(image)
    df_val_y.append(np.array(image))

# %%
callbacks = [
tf.keras.callbacks.EarlyStopping(
    monitor='val_loss', min_delta=0, patience = 10, verbose=2,
    mode='auto', baseline=None, restore_best_weights=True
)
]

# %%
with open('data1','wb') as f: pickle.dump([df_train_x,df_train_y,df_test_x,df_test_y,df_val_x,df_val_y], f)

# %%
with open('data','rb') as f: df_train_x,df_train_y,df_test_x,df_test_y,df_val_x,df_val_y = pickle.load(f)

# %%
input_img = tf.keras.Input(shape=(512, 512, 3))
x = tf.keras.layers.Lambda(lambda x: x / 255)(input_img)
x = layers.Conv2D(64, 4,(2, 2), activation='relu', padding='same')(x)
x = layers.BatchNormalization()(x)
x = layers.ReLU()(x)
x = layers.Conv2D(128, 4,(2, 2), activation='relu', padding='same')(x)
x = layers.BatchNormalization()(x)
x = layers.ReLU()(x)
x = layers.Conv2D(256, 4,(2, 2), activation='relu', padding='same')(x)
x = layers.BatchNormalization()(x)
x = layers.ReLU()(x)
x = layers.Conv2D(512, 4,(2, 2), activation='relu', padding='same')(x)
x = layers.BatchNormalization()(x)
x = layers.ReLU()(x)
encoded = x

# at this point the representation is (4, 4, 8) i.e. 128-dimensional

x = layers.Conv2DTranspose(512, 4, (1, 1), activation='relu', padding='same')(encoded)
x = layers.BatchNormalization()(x)
x = layers.Conv2DTranspose(256, 4,(2, 2), activation='relu', padding='same')(x)
x = layers.BatchNormalization()(x)
x = layers.Conv2DTranspose(128, 4,(2, 2), activation='relu',padding='same')(x)
x = layers.BatchNormalization()(x)
x = layers.Conv2DTranspose(64, 4,(2, 2), activation='relu',padding='same')(x)
x = layers.BatchNormalization()(x)
x = layers.Conv2DTranspose(32, 4,(2, 2), activation='relu',padding='same')(x)
x = layers.BatchNormalization()(x)
decoded = layers.Conv2D(1, (3, 3),activation = 'sigmoid', padding='same')(x)


autoencoder = tf.keras.Model(input_img, decoded)
autoencoder.compile(optimizer=tf.optimizers.Adam(learning_rate=1e-2), loss='binary_crossentropy')

# %%
autoencoder.summary()
# Out:
# Model: "functional_5"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# ...
# input_3 (InputLayer)         [(None, 512, 512, 3)]     0
# _________________________________________________________________
# lambda_2 (Lambda)            (None, 512, 512, 3)       0
# _________________________________________________________________
# conv2d_10 (Conv2D)           (None, 256, 256, 64)      3136
# _________________________________________________________________
# batch_normalization_18 (Batc (None, 256, 256, 64)      256
# _________________________________________________________________
# re_lu_8 (ReLU)               (None, 256, 256, 64)      0
# _________________________________________________________________
# conv2d_11 (Conv2D)           (None, 128, 128, 128)     131200
# _________________________________________________________________
# batch_normalization_19 (Batc (None, 128, 128, 128)     512
# ...

# %%
    log_dir = "logs/fit/" + '/my_model_1e-2'
    tensorboard_callback = tf.keras.callbacks.TensorBoard(log_dir=log_dir, histogram_freq=1)
    autoencoder.fit(x_train, y_train,
                epochs=100,
                batch_size=12,
                shuffle=True,
                validation_split=0.1,
               verbose = 2,
                   callbacks=callbacks+ [tensorboard_callback])
# Out:
# Epoch 1/100
# WARNING:tensorflow:Callbacks method `on_train_batch_end` is slow compared to the batch time (batch time: 0.0108s vs `on_train_batch_end` time: 1.2068s). Check your callbacks.
# 75/75 - 40s - loss: 0.4027 - val_loss: 2.5551
# Epoch 2/100
# 75/75 - 38s - loss: 0.3472 - val_loss: 1.2289
# Epoch 3/100
# 75/75 - 38s - loss: 0.3362 - val_loss: 0.5871
# Epoch 4/100
# 75/75 - 38s - loss: 0.3260 - val_loss: 0.5433
# Epoch 5/100
# 75/75 - 38s - loss: 0.3175 - val_loss: 0.5953
# Epoch 6/100
# 75/75 - 38s - loss: 0.3104 - val_loss: 0.9869
# Epoch 7/100
# 75/75 - 38s - loss: 0.2972 - val_loss: 0.3547
# Epoch 8/100
# 75/75 - 38s - loss: 0.2818 - val_loss: 0.3498
# Epoch 9/100
# 75/75 - 38s - loss: 0.2713 - val_loss: 0.3473
# Epoch 10/100
# 75/75 - 38s - loss: 0.2652 - val_loss: 0.3825
# Epoch 11/100
# 75/75 - 38s - loss: 0.2542 - val_loss: 0.3424
# Epoch 12/100
# 75/75 - 38s - loss: 0.2363 - val_loss: 0.3966
# Epoch 13/100
# 75/75 - 38s - loss: 0.2293 - val_loss: 0.2977
# ...

# %%
img = cv2.imread('/home/rafa/Desktop/Projects/AVA/test.jpeg', cv2.IMREAD_COLOR)

# %%
resimg = cv2.resize(img,(512,512))
blurred = cv2.GaussianBlur(resimg,(5,5),0)
# imgborder = cv2.Canny(image=blurimg, threshold1=10, threshold2=10)

plt.imshow(imgborder)
wide = cv2.Canny(blurred, 10, 200)
mid = cv2.Canny(blurred, 30, 150)
tight = cv2.Canny(blurred, 200, 240)
# show the output Canny edge maps
cv2.imshow("Wide Edge Map", wide)
cv2.imshow("Mid Edge Map", mid)
cv2.imshow("Tight Edge Map", tight)
cv2.waitKey(0)

# %%
img.shape
# Out:
# (512, 512, 3)

# %%
# (autoencoder.predict(img)*255).astype(int)
# autoencoder.predict(img)[0].shape
img = cv2.imread('/home/rafa/Desktop/Projects/AVA/test_1.jpg', cv2.IMREAD_COLOR)
# img = cv2.GaussianBlur(img,(5,5),cv2.BORDER_DEFAULT)
img = cv2.resize(img,(512,512))
cv2.imwrite('input.jpeg', img)
img = cv2.GaussianBlur(img,(5,5),cv2.BORDER_DEFAULT)
img = np.expand_dims(img, 0)
im = model.predict(img)[0]
# im = (im>0.9).astype(int)
cv2.imwrite('output.jpeg', im*255)
# Out:
# True

# %%
n = 10
plt.figure(figsize=(20, 4))
for i in range(1, n + 1):
    # Display original
    ax = plt.subplot(2, n, i)
    plt.imshow(df_test_x[i])
    ax.get_xaxis().set_visible(False)
    ax.get_yaxis().set_visible(False)

    # Display reconstruction
    ax = plt.subplot(2, n, i + n)
    plt.imshow(decoded_imgs[i])
    plt.gray()
    ax.get_xaxis().set_visible(False)
    ax.get_yaxis().set_visible(False)
plt.show()

# %%
autoencoder.save('saved_model/my_model')
# Out:
# WARNING:tensorflow:From /home/rafa/.local/lib/python3.8/site-packages/tensorflow/python/training/tracking/tracking.py:111: Model.state_updates (from tensorflow.python.keras.engine.training) is deprecated and will be removed in a future version.
# Instructions for updating:
# This property should not be used in TensorFlow 2.0, as updates are applied automatically.
# WARNING:tensorflow:From /home/rafa/.local/lib/python3.8/site-packages/tensorflow/python/training/tracking/tracking.py:111: Layer.updates (from tensorflow.python.keras.engine.base_layer) is deprecated and will be removed in a future version.
# Instructions for updating:
# This property should not be used in TensorFlow 2.0, as updates are applied automatically.
# INFO:tensorflow:Assets written to: saved_model/my_model/assets

# %%
autoencoder = tf.keras.models.load_model('saved_model/my_model_200')

# %%
# %tensorboard --logdir logs/fit/my_model
# Out:
# UsageError: Line magic function `%tensorboard` not found.

# %%
# https://www.youtube.com/watch?v=68HR_eyzk00


"""
@author: Sreenivas Bhattiprolu
"""


IMG_WIDTH = 512
IMG_HEIGHT = 512
IMG_CHANNELS = 3


#Build the model
inputs = tf.keras.layers.Input((IMG_HEIGHT, IMG_WIDTH, IMG_CHANNELS))
s = tf.keras.layers.Lambda(lambda x: x / 255)(inputs)

#Contraction path
c1 = tf.keras.layers.Conv2D(16, (3, 3), activation='relu', kernel_initializer='he_normal', padding='same')(s)
c1 = tf.keras.layers.Dropout(0.1)(c1)
c1 = tf.keras.layers.Conv2D(16, (3, 3), activation='relu', kernel_initializer='he_normal', padding='same')(c1)
p1 = tf.keras.layers.MaxPooling2D((2, 2))(c1)

c2 = tf.keras.layers.Conv2D(32, (3, 3), activation='relu', kernel_initializer='he_normal', padding='same')(p1)
c2 = tf.keras.layers.Dropout(0.1)(c2)
c2 = tf.keras.layers.Conv2D(32, (3, 3), activation='relu', kernel_initializer='he_normal', padding='same')(c2)
p2 = tf.keras.layers.MaxPooling2D((2, 2))(c2)
 
c3 = tf.keras.layers.Conv2D(64, (3, 3), activation='relu', kernel_initializer='he_normal', padding='same')(p2)
c3 = tf.keras.layers.Dropout(0.2)(c3)
c3 = tf.keras.layers.Conv2D(64, (3, 3), activation='relu', kernel_initializer='he_normal', padding='same')(c3)
p3 = tf.keras.layers.MaxPooling2D((2, 2))(c3)
 
c4 = tf.keras.layers.Conv2D(128, (3, 3), activation='relu', kernel_initializer='he_normal', padding='same')(p3)
c4 = tf.keras.layers.Dropout(0.2)(c4)
c4 = tf.keras.layers.Conv2D(128, (3, 3), activation='relu', kernel_initializer='he_normal', padding='same')(c4)
p4 = tf.keras.layers.MaxPooling2D(pool_size=(2, 2))(c4)
 
c5 = tf.keras.layers.Conv2D(256, (3, 3), activation='relu', kernel_initializer='he_normal', padding='same')(p4)
c5 = tf.keras.layers.Dropout(0.3)(c5)
c5 = tf.keras.layers.Conv2D(256, (3, 3), activation='relu', kernel_initializer='he_normal', padding='same')(c5)

#Expansive path 
u6 = tf.keras.layers.Conv2DTranspose(128, (2, 2), strides=(2, 2), padding='same')(c5)
u6 = tf.keras.layers.concatenate([u6, c4])
c6 = tf.keras.layers.Conv2D(128, (3, 3), activation='relu', kernel_initializer='he_normal', padding='same')(u6)
c6 = tf.keras.layers.Dropout(0.2)(c6)
c6 = tf.keras.layers.Conv2D(128, (3, 3), activation='relu', kernel_initializer='he_normal', padding='same')(c6)
 
u7 = tf.keras.layers.Conv2DTranspose(64, (2, 2), strides=(2, 2), padding='same')(c6)
u7 = tf.keras.layers.concatenate([u7, c3])
c7 = tf.keras.layers.Conv2D(64, (3, 3), activation='relu', kernel_initializer='he_normal', padding='same')(u7)
c7 = tf.keras.layers.Dropout(0.2)(c7)
c7 = tf.keras.layers.Conv2D(64, (3, 3), activation='relu', kernel_initializer='he_normal', padding='same')(c7)
 
u8 = tf.keras.layers.Conv2DTranspose(32, (2, 2), strides=(2, 2), padding='same')(c7)
u8 = tf.keras.layers.concatenate([u8, c2])
c8 = tf.keras.layers.Conv2D(32, (3, 3), activation='relu', kernel_initializer='he_normal', padding='same')(u8)
c8 = tf.keras.layers.Dropout(0.1)(c8)
c8 = tf.keras.layers.Conv2D(32, (3, 3), activation='relu', kernel_initializer='he_normal', padding='same')(c8)
 
u9 = tf.keras.layers.Conv2DTranspose(16, (2, 2), strides=(2, 2), padding='same')(c8)
u9 = tf.keras.layers.concatenate([u9, c1], axis=3)
c9 = tf.keras.layers.Conv2D(16, (3, 3), activation='relu', kernel_initializer='he_normal', padding='same')(u9)
c9 = tf.keras.layers.Dropout(0.1)(c9)
c9 = tf.keras.layers.Conv2D(16, (3, 3), activation='relu', kernel_initializer='he_normal', padding='same')(c9)
 
outputs = tf.keras.layers.Conv2D(1, (1, 1), activation= 'sigmoid')(c9)
 
model = tf.keras.Model(inputs=[inputs], outputs=[outputs])
model.compile(optimizer="adam", loss='binary_crossentropy', metrics=['accuracy'])
model.summary()
# Out:
# Model: "functional_1"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ...
# input_1 (InputLayer)            [(None, 512, 512, 3) 0
# __________________________________________________________________________________________________
# lambda (Lambda)                 (None, 512, 512, 3)  0           input_1[0][0]
# __________________________________________________________________________________________________
# conv2d (Conv2D)                 (None, 512, 512, 16) 448         lambda[0][0]
# __________________________________________________________________________________________________
# dropout (Dropout)               (None, 512, 512, 16) 0           conv2d[0][0]
# __________________________________________________________________________________________________
# conv2d_1 (Conv2D)               (None, 512, 512, 16) 2320        dropout[0][0]
# ...

# %%
# Out:
# Epoch 1/100
# WARNING:tensorflow:Callbacks method `on_train_batch_end` is slow compared to the batch time (batch time: 0.0058s vs `on_train_batch_end` time: 0.1278s). Check your callbacks.
# WARNING:tensorflow:Callbacks method `on_test_batch_end` is slow compared to the batch time (batch time: 0.0030s vs `on_test_batch_end` time: 0.0285s). Check your callbacks.
# 225/225 - 31s - loss: 152591134235820032.0000 - accuracy: 0.8387 - val_loss: 0.5323 - val_accuracy: 0.8427
# Epoch 2/100
# 225/225 - 31s - loss: 0.4968 - accuracy: 0.8462 - val_loss: 0.4757 - val_accuracy: 0.8427
# Epoch 3/100
# 225/225 - 30s - loss: 0.4593 - accuracy: 0.8462 - val_loss: 0.4534 - val_accuracy: 0.8427
# Epoch 4/100
# 225/225 - 31s - loss: 0.4435 - accuracy: 0.8462 - val_loss: 0.4436 - val_accuracy: 0.8427
# Epoch 5/100
# 225/225 - 31s - loss: 0.4364 - accuracy: 0.8462 - val_loss: 0.4393 - val_accuracy: 0.8427
# Epoch 6/100
# ...

# %%
log_dir = "logs/fit/" + '/my_model_u_blur'
tensorboard_callback = tf.keras.callbacks.TensorBoard(log_dir=log_dir, histogram_freq=1)
model.fit(x_train, y_train,
            epochs=100,
            batch_size=4,
            shuffle=True,
            validation_split=0.1,
           verbose = 2,
         callbacks=callbacks+ [tensorboard_callback])
# Out:
# Epoch 1/100
# WARNING:tensorflow:From /home/rafa/.local/lib/python3.8/site-packages/tensorflow/python/ops/summary_ops_v2.py:1277: stop (from tensorflow.python.eager.profiler) is deprecated and will be removed after 2020-07-01.
# Instructions for updating:
# use `tf.profiler.experimental.stop` instead.
# WARNING:tensorflow:Callbacks method `on_train_batch_end` is slow compared to the batch time (batch time: 0.0058s vs `on_train_batch_end` time: 0.1510s). Check your callbacks.
# WARNING:tensorflow:Callbacks method `on_test_batch_end` is slow compared to the batch time (batch time: 0.0032s vs `on_test_batch_end` time: 0.0287s). Check your callbacks.
# 225/225 - 31s - loss: 0.4281 - accuracy: 0.8401 - val_loss: 0.3860 - val_accuracy: 0.8427
# Epoch 2/100
# 225/225 - 31s - loss: 0.3600 - accuracy: 0.8462 - val_loss: 0.3606 - val_accuracy: 0.8427
# Epoch 3/100
# 225/225 - 31s - loss: 0.3546 - accuracy: 0.8462 - val_loss: 0.3565 - val_accuracy: 0.8427
# Epoch 4/100
# ...

# %%
model.save('saved_model/my_model_blur')
# Out:
# WARNING:tensorflow:From /home/rafa/.local/lib/python3.8/site-packages/tensorflow/python/training/tracking/tracking.py:111: Model.state_updates (from tensorflow.python.keras.engine.training) is deprecated and will be removed in a future version.
# Instructions for updating:
# This property should not be used in TensorFlow 2.0, as updates are applied automatically.
# WARNING:tensorflow:From /home/rafa/.local/lib/python3.8/site-packages/tensorflow/python/training/tracking/tracking.py:111: Layer.updates (from tensorflow.python.keras.engine.base_layer) is deprecated and will be removed in a future version.
# Instructions for updating:
# This property should not be used in TensorFlow 2.0, as updates are applied automatically.
# INFO:tensorflow:Assets written to: saved_model/my_model_blur/assets
